# %%
# !pip install -q google-generativeai tavily-python

# %%
import os
import google.generativeai as genai

# Gemini API key
os.environ["GOOGLE_API_KEY"] = "AIzaSyA7AYprgkC_DG31Fxjt7vY6Z1J8M2W1KwU"

# Tavily API key
os.environ["TAVILY_API_KEY"] = "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"

# Configure Gemini
genai.configure(api_key=os.environ["GOOGLE_API_KEY"])

# %%
from tavily import TavilyClient

class WebResearchAgent:
    def __init__(self, topic):
        self.topic = topic
        self.questions = []
        self.research_data = {}
        self.model = genai.GenerativeModel(model_name="models/gemini-1.5-flash-latest")
        self.tavily = TavilyClient()

    def generate_questions(self):
        prompt = f"Generate 5 to 6 insightful and well-structured research questions about the topic: {self.topic}."
        response = self.model.generate_content(prompt)
        self.questions = [
            q.strip("1234567890). ").strip()
            for q in response.text.strip().split("\n")
            if q.strip()
        ]

        # 👇 Print the generated questions
        print("\n📋 Generated Research Questions:")
        for i, q in enumerate(self.questions, 1):
            print(f"{i}. {q}")

    def search_web(self):
        for question in self.questions:
            safe_query = question[:400]
            try:
                result = self.tavily.search(query=safe_query, search_depth="advanced", include_answer=True)
                self.research_data[question] = [
                    {"title": r.get("title"), "content": r.get("content")}
                    for r in result.get("results", [])
                ]
            except Exception as e:
                self.research_data[question] = [{"title": "Search Error", "content": str(e)}]


    def generate_report(self):
        report = f"# 🧾 Research Report on **{self.topic}**\n\n"
        report += "## 🧠 Introduction\nThis report is generated by an AI agent using the ReAct pattern (Reasoning + Acting).\n\n"
        for question in self.questions:
            report += f"### ❓ {question}\n"
            if self.research_data.get(question):
                for item in self.research_data[question]:
                    report += f"- **{item['title']}**: {item['content']}\n"
            else:
                report += "- No relevant results found.\n"
            report += "\n"
        report += "## ✅ Conclusion\nThis concludes the structured research conducted by the AI agent.\n"
        return report

# %%
# Example Topic
topic = input('Enter the topic you want to explore:')

agent = WebResearchAgent(topic)
agent.generate_questions()
agent.search_web()
final_report = agent.generate_report()
# Out:
# Enter the topic you want to explore:AI in Education Sector
# ERROR:tornado.access:503 POST /v1beta/models/gemini-1.5-flash-latest:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 17197.41ms
# 📋 Generated Research Questions:
# 1. **How do different pedagogical approaches (e.g., personalized learning, collaborative learning) influence the effectiveness of AI-powered educational tools, and what are the optimal methods for integrating AI into these approaches to maximize student learning outcomes?** (This question explores the interplay between AI and established teaching methods, focusing on practical implementation and effectiveness
# ...

# %%
from IPython.display import Markdown
display(Markdown(final_report))
# Out:
# # 🧾 Research Report on **AI in Education Sector**
#
# ## 🧠 Introduction
# This report is generated by an AI agent using the ReAct pattern (Reasoning + Acting).
#
# ### ❓ **How do different pedagogical approaches (e.g., personalized learning, collaborative learning) influence the effectiveness of AI-powered educational tools, and what are the optimal methods for integrating AI into these approaches to maximize student learning outcomes?** (This question explores the interplay between AI and established teaching methods, focusing on practical implementation and effectiveness
# ...
